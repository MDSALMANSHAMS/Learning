# %%
# %cd C:\My files\Learning\Python_programming\7_DSA\DSA_for_AI
# Out:
# C:\My files\Learning\Python_programming\7_DSA\DSA_for_AI
# c:\My files\Learning\venv3.9\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# Big O: Worst-case performance

# %%
import matplotlib.pyplot as plt
from PIL import Image

# Path to your image
image_path = "Big_O.png"   # replace with your image path

# Load image
img = Image.open(image_path)

# Plot image
plt.figure()
plt.imshow(img)
plt.axis("off")   # Hide axis
plt.title("Loaded Image")
plt.show()
